# %% [markdown]
# # Initialize Modules

# %%
pip install ipywidgets
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting ipywidgets
#   Downloading ipywidgets-8.0.6-py3-none-any.whl (138 kB)
#      -------------------------------------- 138.3/138.3 kB 1.0 MB/s eta 0:00:00
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\user\appdata\roaming\python\python310\site-packages (from ipywidgets) (6.15.3)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\user\appdata\roaming\python\python310\site-packages (from ipywidgets) (8.5.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\user\appdata\roaming\python\python310\site-packages (from ipywidgets) (5.9.0)
# Collecting widgetsnbextension~=4.0.7 (from ipywidgets)
#   Downloading widgetsnbextension-4.0.7-py3-none-any.whl (2.1 MB)
#      ---------------------------------------- 2.1/2.1 MB 2.9 MB/s eta 0:00:00
# Collecting jupyterlab-widgets~=3.0.7 (from ipywidgets)
#   Downloading jupyterlab_widgets-3.0.7-py3-none-any.whl (198 kB)
#      -------------------------------------- 198.2/198.2 kB 4.0 MB/s eta 0:00:00
# Requirement already satisfied: debugpy>=1.0 in c:\users\user\appdata\roaming\python\python310\site-packages (from ipykernel>=4.5.1->ipywidgets) (1.6.3)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\user\appdata\roaming\python\python310\site-packages (from ipykernel>=4.5.1->ipywidgets) (8.2.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\user\appdata\roaming\python\python310\site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\users\user\appdata\roaming\python\python310\site-packages (from ipykernel>=4.5.1->ipywidgets) (1.5.5)
# Requirement already satisfied: packaging in c:\users\user\appdata\roaming\python\python310\site-packages (from ipykernel>=4.5.1->ipywidgets) (21.3)
# Requirement already satisfied: psutil in c:\users\user\appdata\roaming\python\python310\site-packages (from ipykernel>=4.5.1->ipywidgets) (5.9.2)
# Requirement already satisfied: pyzmq>=17 in c:\users\user\appdata\roaming\python\python310\site-packages (from ipykernel>=4.5.1->ipywidgets) (24.0.1)
# Requirement already satisfied: tornado>=6.1 in c:\users\user\appdata\roaming\python\python310\site-packages (from ipykernel>=4.5.1->ipywidgets) (6.2)
# Requirement already satisfied: backcall in c:\users\user\appdata\roaming\python\python310\site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: decorator in c:\users\user\appdata\roaming\python\python310\site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\user\appdata\roaming\python\python310\site-packages (from ipython>=6.1.0->ipywidgets) (0.17.2)
# Requirement already satisfied: pickleshare in c:\users\user\appdata\roaming\python\python310\site-packages (from ipython>=6.1.0->ipywidgets) (0.7.5)
# Requirement already satisfied: prompt-toolkit<3.1.0,>3.0.1 in c:\users\user\appdata\roaming\python\python310\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.31)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\user\appdata\roaming\python\python310\site-packages (from ipython>=6.1.0->ipywidgets) (2.13.0)
# Requirement already satisfied: stack-data in c:\users\user\appdata\roaming\python\python310\site-packages (from ipython>=6.1.0->ipywidgets) (0.5.1)
# Requirement already satisfied: colorama in c:\users\user\appdata\roaming\python\python310\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.5)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in c:\users\user\appdata\roaming\python\python310\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.7.1)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\user\appdata\roaming\python\python310\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (5.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\appdata\roaming\python\python310\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (2.8.2)
# Requirement already satisfied: wcwidth in c:\users\user\appdata\roaming\python\python310\site-packages (from prompt-toolkit<3.1.0,>3.0.1->ipython>=6.1.0->ipywidgets) (0.2.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\user\appdata\roaming\python\python310\site-packages (from packaging->ipykernel>=4.5.1->ipywidgets) (3.0.9)
# Requirement already satisfied: executing in c:\users\user\appdata\roaming\python\python310\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (1.1.0)
# Requirement already satisfied: asttokens in c:\users\user\appdata\roaming\python\python310\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.0.8)
# Requirement already satisfied: pure-eval in c:\users\user\appdata\roaming\python\python310\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\user\appdata\roaming\python\python310\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (3.2.0)
# Requirement already satisfied: pywin32>=300 in c:\users\user\appdata\roaming\python\python310\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (304)
# Requirement already satisfied: six>=1.5 in c:\users\user\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (1.16.0)
# Installing collected packages: widgetsnbextension, jupyterlab-widgets, ipywidgets
# Successfully installed ipywidgets-8.0.6 jupyterlab-widgets-3.0.7 widgetsnbextension-4.0.7
# Note: you may need to restart the kernel to use updated packages.

# %%
from shapely import geometry
import geopandas as gpd
import pandas as pd
import os
import numpy as np
from tqdm.notebook import tqdm

# %% [markdown]
# # Make polygons out of coordinates given from csv file

# %%
coord_list = pd.read_csv("Coordinates-Binning3.csv") # read csv file that contains the enclosed coordinates 
def Coord_lister(Loc_Column):   # make a polygon out of the enclosed coordinates
    crs = {'init': 'epsg:4326'}
    x = Loc_Column.to_list()
    pointList = [item for item in x if str(item) != 'nan']
    pointL = []
    for x in tqdm(pointList):
        y = eval(x)
        pointL.append(y)
    poly = geometry.Polygon(pointL)
    spoly = gpd.GeoSeries([poly],crs=crs)
    return spoly

df_coordlist = pd.DataFrame(coord_list)
df_coordlist1 = list(df_coordlist.columns)
df_coordlist1.pop(0)
df_coordlist1
# Out:
# ['HE shop', 'Crusher', 'Annex A', 'Carmen Pit']

# %%
Location_list = []
Location_list_names = df_coordlist1
for area_loc in tqdm(df_coordlist1):
    Location_list.append(Coord_lister(coord_list[area_loc]))
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
# C:\Users\User\AppData\Roaming\Python\Python310\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
#   0%|          | 0/6 [00:00<?, ?it/s]
# C:\Users\User\AppData\Roaming\Python\Python310\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
#   0%|          | 0/6 [00:00<?, ?it/s]
# C:\Users\User\AppData\Roaming\Python\Python310\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
#   0%|          | 0/10 [00:00<?, ?it/s]
# C:\Users\User\AppData\Roaming\Python\Python310\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)

# %%
file = '33854 Feb.csv'
crs = {'init': 'epsg:4326'}

#Create a geoseries holding the single polygon. Coordinates in counter-clockwise order
#pointList = [(10.325852, 123.726840), (10.331532, 123.718828), (10.337319, 123.724241), (10.341579, 123.727525), (10.340266, 123.732830), (10.333982, 123.733516)]

#Create geodataframe of points
dfcsv = pd.read_csv(file)
dfcsv
# Out:
#                        Time   Latitude   Longitude  VehicleSpeed[km/h]  \
# 0       2023-02-04 23:00:46  10.336249  123.721581                 0.0
# 1       2023-02-04 23:00:47  10.336246  123.721581                 0.0
# 2       2023-02-04 23:00:48  10.336243  123.721581                 0.0
# 3       2023-02-04 23:00:49  10.336239  123.721573                 0.0
# 4       2023-02-04 23:00:50  10.336236  123.721573                 0.0
# ...                     ...        ...         ...                 ...
# 568837  2023-02-12 00:21:32  10.323801  123.718292                 3.6
# 568838  2023-02-12 00:21:33  10.323808  123.718285                 3.0
# 568839  2023-02-12 00:21:34  10.323814  123.718285                 2.6
# 568840  2023-02-12 00:21:35  10.323816  123.718277                 2.9
# 568841  2023-02-12 00:21:36  10.323821  123.718277                 4.0
#
#         Waiting Time
# 0                1.0
# 1                1.0
# 2                1.0
# 3                1.0
# 4                1.0
# ...              ...
# 568837           0.0
# 568838           0.0
# 568839           0.0
# 568840           0.0
# 568841           0.0
#
# [568842 rows x 5 columns]

# %%
geometry = [geometry.Point(xy) for xy in zip(dfcsv.Latitude, dfcsv.Longitude)]
dfpoints = gpd.GeoDataFrame(dfcsv, crs=crs, geometry=geometry)
dfpoints
# Out:
# C:\Users\User\AppData\Roaming\Python\Python310\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
#                        Time   Latitude   Longitude  VehicleSpeed[km/h]  \
# 0       2023-02-04 23:00:46  10.336249  123.721581                 0.0
# 1       2023-02-04 23:00:47  10.336246  123.721581                 0.0
# 2       2023-02-04 23:00:48  10.336243  123.721581                 0.0
# 3       2023-02-04 23:00:49  10.336239  123.721573                 0.0
# 4       2023-02-04 23:00:50  10.336236  123.721573                 0.0
# ...                     ...        ...         ...                 ...
# 568837  2023-02-12 00:21:32  10.323801  123.718292                 3.6
# 568838  2023-02-12 00:21:33  10.323808  123.718285                 3.0
# 568839  2023-02-12 00:21:34  10.323814  123.718285                 2.6
# 568840  2023-02-12 00:21:35  10.323816  123.718277                 2.9
# 568841  2023-02-12 00:21:36  10.323821  123.718277                 4.0
#
#         Waiting Time                    geometry
# 0                1.0  POINT (10.33625 123.72158)
# 1                1.0  POINT (10.33625 123.72158)
# 2                1.0  POINT (10.33624 123.72158)
# 3                1.0  POINT (10.33624 123.72157)
# 4                1.0  POINT (10.33624 123.72157)
# ...              ...                         ...
# 568837           0.0  POINT (10.32380 123.71829)
# 568838           0.0  POINT (10.32381 123.71828)
# 568839           0.0  POINT (10.32381 123.71828)
# 568840           0.0  POINT (10.32382 123.71828)
# 568841           0.0  POINT (10.32382 123.71828)
#
# [568842 rows x 6 columns]

# %%
#Create a subset dataframe of points within the polygon
for x,y in tqdm(zip(Location_list, Location_list_names)):
    dfpoints.loc[dfpoints.within(x.geometry.iloc[0]), "Location"] = y
dfpoints.pivot_table(index = "Location")
dfpoints.loc[dfpoints["Location"].isna(), "Location"] = "Others"
dfpoints
# Out:
# 0it [00:00, ?it/s]
# C:\Users\User\AppData\Local\Temp\ipykernel_8692\1452893405.py:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   dfpoints.pivot_table(index = "Location")
#                        Time   Latitude   Longitude  VehicleSpeed[km/h]  \
# 0       2023-02-04 23:00:46  10.336249  123.721581                 0.0
# 1       2023-02-04 23:00:47  10.336246  123.721581                 0.0
# 2       2023-02-04 23:00:48  10.336243  123.721581                 0.0
# 3       2023-02-04 23:00:49  10.336239  123.721573                 0.0
# 4       2023-02-04 23:00:50  10.336236  123.721573                 0.0
# ...                     ...        ...         ...                 ...
# 568837  2023-02-12 00:21:32  10.323801  123.718292                 3.6
# 568838  2023-02-12 00:21:33  10.323808  123.718285                 3.0
# 568839  2023-02-12 00:21:34  10.323814  123.718285                 2.6
# 568840  2023-02-12 00:21:35  10.323816  123.718277                 2.9
# 568841  2023-02-12 00:21:36  10.323821  123.718277                 4.0
#
#         Waiting Time                    geometry Location
# 0                1.0  POINT (10.33625 123.72158)  Crusher
# 1                1.0  POINT (10.33625 123.72158)  Crusher
# 2                1.0  POINT (10.33624 123.72158)  Crusher
# 3                1.0  POINT (10.33624 123.72157)  Crusher
# 4                1.0  POINT (10.33624 123.72157)  Crusher
# ...              ...                         ...      ...
# 568837           0.0  POINT (10.32380 123.71829)   Others
# 568838           0.0  POINT (10.32381 123.71828)   Others
# 568839           0.0  POINT (10.32381 123.71828)   Others
# 568840           0.0  POINT (10.32382 123.71828)   Others
# 568841           0.0  POINT (10.32382 123.71828)   Others
#
# [568842 rows x 7 columns]

# %%
print("Data Successfully Combined")
export_state = False
while not export_state:
    export_path = input("Please input export path directory \n")
    if os.path.exists(export_path) == False:
        print("Please input a correct file path")
    else:
        export_state = True
csv_fname = input("Please input filename")
export_fpath = export_path + "\\" + csv_fname + ".csv"
print(export_fpath)
dfpoints.to_csv(path_or_buf = export_fpath, index = False)
# Out:
# Data Successfully Combined
# Please input export path directory
#  D:\KOmatsu\9. 1st Assignment - CCC\1.2 Technical Reports\2023_04_20 Payload Report and HD785 Peformance\Payload\Performance\Feb 33854 Processed
# Please input filename 33854 Processed with Loc
# D:\KOmatsu\9. 1st Assignment - CCC\1.2 Technical Reports\2023_04_20 Payload Report and HD785 Peformance\Payload\Performance\Feb 33854 Processed\33854 Processed with Loc.csv

# %%
dfpoints.drop_duplicates(keep = False)
# Out:
#                        Time   Latitude   Longitude  VehicleSpeed[km/h]  \
# 0       2023-02-04 23:00:46  10.336249  123.721581                 0.0
# 1       2023-02-04 23:00:47  10.336246  123.721581                 0.0
# 2       2023-02-04 23:00:48  10.336243  123.721581                 0.0
# 3       2023-02-04 23:00:49  10.336239  123.721573                 0.0
# 4       2023-02-04 23:00:50  10.336236  123.721573                 0.0
# ...                     ...        ...         ...                 ...
# 568837  2023-02-12 00:21:32  10.323801  123.718292                 3.6
# 568838  2023-02-12 00:21:33  10.323808  123.718285                 3.0
# 568839  2023-02-12 00:21:34  10.323814  123.718285                 2.6
# 568840  2023-02-12 00:21:35  10.323816  123.718277                 2.9
# 568841  2023-02-12 00:21:36  10.323821  123.718277                 4.0
#
#         Waiting Time                    geometry Location
# 0                1.0  POINT (10.33625 123.72158)  Crusher
# 1                1.0  POINT (10.33625 123.72158)  Crusher
# 2                1.0  POINT (10.33624 123.72158)  Crusher
# 3                1.0  POINT (10.33624 123.72157)  Crusher
# 4                1.0  POINT (10.33624 123.72157)  Crusher
# ...              ...                         ...      ...
# 568837           0.0  POINT (10.32380 123.71829)   Others
# 568838           0.0  POINT (10.32381 123.71828)   Others
# 568839           0.0  POINT (10.32381 123.71828)   Others
# 568840           0.0  POINT (10.32382 123.71828)   Others
# 568841           0.0  POINT (10.32382 123.71828)   Others
#
# [568820 rows x 7 columns]
